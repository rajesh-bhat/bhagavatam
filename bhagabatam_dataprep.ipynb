# %%
import pandas as pd

# %%
gt = pd.read_csv('canto2.csv', encoding='utf-8')

# %%
def find_OCR(sent_id):
    file = open('tesseract-ocr-re-master/scripts/' + canto_name + '_eng/out/' + str(sent_id) + '.txt', 'r')
    return(file.read().strip())

# %%
canto_name = 'canto2'
gt['OCR'] = gt['ids'].apply(find_OCR)

# %%
gt
# Out:
#                    ids                     sentences  \
# 0     2.1.invocation.1  oṁ namo bhagavate vāsudevāya
# 1              2.1.1.1                śrī-śuka uvāca
# 2              2.1.2.1         śrotavyādīni rājendra
# 3              2.1.2.2        nṛṇāṁ santi sahasraśaḥ
# 4              2.1.2.3        apaśyatām ātma-tattvaṁ
# 5              2.1.2.4          gṛheṣu gṛha-medhinām
# 6              2.1.3.1        nidrayā hriyate naktaṁ
# 7              2.1.3.2         vyavāyena ca vā vayaḥ
# 8              2.1.3.3         divā cārthehayā rājan
# 9              2.1.3.4          kuṭumba-bharaṇena vā
# 10             2.1.4.1         dehāpatya-kalatrādiṣv
# 11             2.1.4.2      ātma-sainyeṣv asatsv api
# 12             2.1.4.3       teṣāṁ pramatto nidhanaṁ
# 13             2.1.4.4        paśyann api na paśyati
# 14             2.1.5.1       tasmād bhārata sarvātmā
# 15             2.1.5.2         bhagavān īśvaro hariḥ
# 16             2.1.5.3      śrotavyaḥ kīrtitavyaś ca
# ...
